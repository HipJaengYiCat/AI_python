# %% [markdown]
# <a href="https://colab.research.google.com/github/seunghee0518/AI_python/blob/main/EfficientNet_b0_train_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## trina/ test 나눠서 학습

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## 학습 코드
import warnings
warnings.filterwarnings('ignore')

from glob import glob
from tqdm import tqdm
import cv2
#import timm
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import f1_score, accuracy_score
import gc

import pandas as pd
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset

# from efficientnet_pytorch import EfficientNet
# model_name = 'efficientnet-b0'  # b5

# image_size = EfficientNet.get_image_size(model_name)
# print(image_size)
# model = EfficientNet.from_pretrained(model_name, num_classes=88)

# %%
np.array(train_labels)
# Out:
# array([72, 15, 72, ..., 28, 84, 55])

# %%
## 데이타 로드!!
batch_size  = 128
random_seed = 1234
random.seed(random_seed)
torch.manual_seed(random_seed)

train_imgs = np.load('/content/drive/MyDrive/DACON_이상치 탐지 알고리즘 경진대회/train_imgs_224.npy')
## make dataset
from torchvision import transforms, datasets
# data_path = 'president/president_data'  # class 별 폴더로 나누어진걸 확 가져와서 라벨도 달아준다
# train_dataset = datasets.ImageFolder(data_path,
#                                      transforms.Compose([
#                                      transforms.Resize((224, 224)),
#                                      transforms.ToTensor(), # 이미지 데이터를 tensor로 바꿔준다.
#                                      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # Normalize는 많은 이미지의 평균, 표준편차로 정함(보통 많이 하는 값이라고함)
#                                 ]))

device = torch.device('cuda')

## 이미지 경로
#train_png = sorted(glob('/content/drive/Othercomputers/내 MacBook Pro/open/train/*.png'))
#test_png = sorted(glob('/content/drive/Othercomputers/내 MacBook Pro/open/train/*.png'))

train_y = pd.read_csv("/content/drive/Othercomputers/내 MacBook Pro/open/train_df.csv")

train_labels = train_y["label"]

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}

train_labels = [label_unique[k] for k in train_labels]


class Custom_dataset_3(Dataset):
    def __init__(self, img_paths, labels, mode='train'):
        self.img_paths = img_paths
        self.labels = labels
        self.mode=mode
    def __len__(self):
        return len(self.img_paths)
    def __getitem__(self, idx):
        img = self.img_paths[idx]
        img = transforms.ToTensor()(img)
        img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
        if self.mode=='test':
            pass
        label = self.labels[idx]
        return img, label

train_dataset = Custom_dataset_3(np.array(train_imgs), np.array(train_labels), mode='train')


#img = transforms.ToTensor()(img)
## data split
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
Y = [train_dataset[x][1] for x in range(len(train_dataset))]

train_idx, test_idx = train_test_split(list(range(len(train_dataset))), stratify=Y, test_size=0.3, random_state=random_seed)

datasets = {} # 데이터셋을 담을 딕셔너리
datasets['train'] = Subset(train_dataset, train_idx)
datasets['test']  = Subset(train_dataset, test_idx)

## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],
                                                  batch_size=batch_size, shuffle=True,
                                                  num_workers=4)
dataloaders['test']  = torch.utils.data.DataLoader(datasets['test'],
                                                  batch_size=batch_size, shuffle=False,
                                                  num_workers=4)
batch_num['train'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['test'])
print('batch_size : %d,  train/test(데이터셋개수/배치사이즈) : %d / %d' % (batch_size, batch_num['train'],batch_num['test']))
# Out:
# batch_size : 128,  train/test : 24 / 11

# %%
def score_function(real, pred):
    score = f1_score(real, pred, average="macro")
    return score

# %%
# 참고 블로그 : https://keep-steady.tistory.com/35
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    # train_loss, train_acc, valid_loss, valid_acc f1 = [], [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs))# - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            
            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))
           
            # deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu

model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(), 
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# 모델 학습
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.71 Acc: 76.9
# test Loss: 1.11 Acc: 84.4
# ==> best model saved - 0 / 84.4
# Epoch 1/99
# ----------
# train Loss: 0.77 Acc: 85.4
# test Loss: 0.80 Acc: 85.4
# ==> best model saved - 1 / 85.4
# Epoch 2/99
# ----------
# train Loss: 0.50 Acc: 87.9
# test Loss: 0.63 Acc: 87.5
# ==> best model saved - 2 / 87.5
# Epoch 3/99
# ----------
# train Loss: 0.39 Acc: 89.5
# test Loss: 0.56 Acc: 87.9
# ==> best model saved - 3 / 87.9
# Epoch 4/99
# ----------
# train Loss: 0.30 Acc: 91.3
# test Loss: 0.46 Acc: 89.3
# ==> best model saved - 4 / 89.3
# Epoch 5/99
# ----------
# train Loss: 0.24 Acc: 93.2
# test Loss: 0.46 Acc: 89.5
# ==> best model saved - 5 / 89.5
# Epoch 6/99
# ----------
# train Loss: 0.19 Acc: 94.1
# test Loss: 0.48 Acc: 89.3
# Epoch 7/99
# ----------
# train Loss: 0.17 Acc: 95.3
# test Loss: 0.45 Acc: 87.8
# Epoch 8/99
# ----------
# train Loss: 0.15 Acc: 95.6
# test Loss: 0.35 Acc: 90.5
# ==> best model saved - 8 / 90.5
# Epoch 9/99
# ----------
# train Loss: 0.12 Acc: 96.7
# test Loss: 0.33 Acc: 90.8
# ==> best model saved - 9 / 90.8
# Epoch 10/99
# ----------
# train Loss: 0.09 Acc: 97.2
# test Loss: 0.29 Acc: 92.1
# ==> best model saved - 10 / 92.1
# Epoch 11/99
# ----------
# train Loss: 0.07 Acc: 98.3
# test Loss: 0.40 Acc: 90.6
# Epoch 12/99
# ----------
# train Loss: 0.07 Acc: 98.2
# test Loss: 0.39 Acc: 89.3
# Epoch 13/99
# ----------
# train Loss: 0.05 Acc: 98.7
# test Loss: 0.31 Acc: 92.0
# Epoch 14/99
# ----------
# train Loss: 0.04 Acc: 99.2
# test Loss: 0.33 Acc: 91.4
# Epoch 15/99
# ----------
# train Loss: 0.03 Acc: 99.4
# test Loss: 0.64 Acc: 88.0
# Epoch 16/99
# ----------
# train Loss: 0.03 Acc: 99.2
# test Loss: 0.31 Acc: 91.7
# Epoch 17/99
# ----------
# train Loss: 0.04 Acc: 99.2
# test Loss: 0.46 Acc: 88.7
# Epoch 18/99
# ----------
# train Loss: 0.03 Acc: 99.3
# test Loss: 0.30 Acc: 91.7
# Epoch 19/99
# ----------
# train Loss: 0.02 Acc: 99.5
# test Loss: 0.27 Acc: 93.5
# ==> best model saved - 19 / 93.5
# Epoch 20/99
# ----------
# train Loss: 0.01 Acc: 99.8
# test Loss: 0.29 Acc: 93.1
# Epoch 21/99
# ----------
# train Loss: 0.01 Acc: 99.8
# test Loss: 0.35 Acc: 93.1
# Epoch 22/99
# ----------
# train Loss: 0.01 Acc: 99.6
# test Loss: 0.29 Acc: 93.7
# ==> best model saved - 22 / 93.7
# Epoch 23/99
# ----------
# train Loss: 0.01 Acc: 99.9
# test Loss: 0.26 Acc: 94.0
# ==> best model saved - 23 / 94.0
# Epoch 24/99
# ----------
# train Loss: 0.01 Acc: 99.9
# test Loss: 0.28 Acc: 93.6
# Epoch 25/99
# ----------
# train Loss: 0.01 Acc: 99.9
# test Loss: 0.29 Acc: 93.5
# Epoch 26/99
# ----------
# train Loss: 0.01 Acc: 99.8
# test Loss: 0.29 Acc: 93.1
# Epoch 27/99
# ----------
# train Loss: 0.01 Acc: 99.8
# test Loss: 0.27 Acc: 93.5
# Epoch 28/99
# ----------
# train Loss: 0.01 Acc: 99.8
# test Loss: 0.34 Acc: 92.9
# Epoch 29/99
# ----------
# train Loss: 0.01 Acc: 99.8
# test Loss: 0.36 Acc: 92.7
# Epoch 30/99
# ----------
# train Loss: 0.01 Acc: 99.9
# test Loss: 0.33 Acc: 93.3
# Epoch 31/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.29 Acc: 93.4
# Epoch 32/99
# ----------
# train Loss: 0.01 Acc: 99.9
# test Loss: 0.28 Acc: 93.6
# Epoch 33/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 93.5
# Epoch 34/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.30 Acc: 93.7
# Epoch 35/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.0
# Epoch 36/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.30 Acc: 93.7
# Epoch 37/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.28 Acc: 94.5
# ==> best model saved - 37 / 94.5
# Epoch 38/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.29 Acc: 93.8
# Epoch 39/99
# ----------
# train Loss: 0.01 Acc: 99.9
# test Loss: 0.32 Acc: 93.3
# Epoch 40/99
# ----------
# train Loss: 0.00 Acc: 99.8
# test Loss: 0.27 Acc: 94.2
# Epoch 41/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.26 Acc: 94.2
# Epoch 42/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.1
# Epoch 43/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.38 Acc: 93.2
# Epoch 44/99
# ----------
# train Loss: 0.01 Acc: 99.9
# test Loss: 0.29 Acc: 93.9
# Epoch 45/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.31 Acc: 93.5
# Epoch 46/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.28 Acc: 93.8
# Epoch 47/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.26 Acc: 94.1
# Epoch 48/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.29 Acc: 93.9
# Epoch 49/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.0
# Epoch 50/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 93.6
# Epoch 51/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.2
# Epoch 52/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.0
# Epoch 53/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 93.9
# Epoch 54/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.0
# Epoch 55/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.0
# Epoch 56/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.28 Acc: 94.4
# Epoch 57/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.28 Acc: 94.4
# Epoch 58/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.2
# Epoch 59/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.30 Acc: 93.6
# Epoch 60/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.33 Acc: 93.5
# Epoch 61/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.32 Acc: 93.5
# Epoch 62/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.33 Acc: 93.5
# Epoch 63/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 93.8
# Epoch 64/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.31 Acc: 94.0
# Epoch 65/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.32 Acc: 93.7
# Epoch 66/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.32 Acc: 93.8
# Epoch 67/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.2
# Epoch 68/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.4
# Epoch 69/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.1
# Epoch 70/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.1
# Epoch 71/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.2
# Epoch 72/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.5
# Epoch 73/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.3
# Epoch 74/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.29 Acc: 94.2
# Epoch 75/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.1
# Epoch 76/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.1
# Epoch 77/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.3
# Epoch 78/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.4
# Epoch 79/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.4
# Epoch 80/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.3
# Epoch 81/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.28 Acc: 94.2
# Epoch 82/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.28 Acc: 94.4
# Epoch 83/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.28 Acc: 94.3
# Epoch 84/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.28 Acc: 94.1
# Epoch 85/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.26 Acc: 94.5
# Epoch 86/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.27 Acc: 94.5
# Epoch 87/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.28 Acc: 94.4
# Epoch 88/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.4
# Epoch 89/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.3
# Epoch 90/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.2
# Epoch 91/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.3
# Epoch 92/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.2
# Epoch 93/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.28 Acc: 94.5
# Epoch 94/99
# ----------
# train Loss: 0.00 Acc: 99.9
# test Loss: 0.29 Acc: 94.5
# Epoch 95/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.6
# ==> best model saved - 95 / 94.6
# Epoch 96/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.29 Acc: 94.5
# Epoch 97/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.4
# Epoch 98/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.5
# Epoch 99/99
# ----------
# train Loss: 0.00 Acc: 100.0
# test Loss: 0.30 Acc: 94.4
# Training complete in 28m 16s
# Best valid Acc: 95 - 94.6
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 95 - 95 / 0.3

# %%
## 학습 결과 검수
def test_and_visualize_model(model, phase = 'test', num_images=4):
    # phase = 'train', 'valid', 'test'
    
    was_training = model.training
    model.eval()
    fig = plt.figure()
    
    running_loss, running_corrects, num_cnt = 0.0, 0, 0

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)  # batch의 평균 loss 출력

            running_loss    += loss.item() * inputs.size(0)
            running_corrects+= torch.sum(preds == labels.data)
            num_cnt += inputs.size(0)  # batch size

    #         if i == 2: break

        test_loss = running_loss / num_cnt
        test_acc  = running_corrects.double() / num_cnt       
        print('test done : loss/acc : %.2f / %.1f' % (test_loss, test_acc*100))

    # 예시 그림 plot
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)        

            # 예시 그림 plot
            for j in range(1, num_images+1):
                ax = plt.subplot(num_images//2, 2, j)
                ax.axis('off')
                ax.set_title('%s : %s -> %s'%(
                    'True' if class_names[str(labels[j].cpu().numpy())]==class_names[str(preds[j].cpu().numpy())] else 'False',
                    class_names[str(labels[j].cpu().numpy())], class_names[str(preds[j].cpu().numpy())]))
                imshow(inputs.cpu().data[j])          
            if i == 0 : break


    model.train(mode=was_training);  # 다시 train모드로
    
    ## TEST!
    test_and_visualize_model(model, phase = 'test')
